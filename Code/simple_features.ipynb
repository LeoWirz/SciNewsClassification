# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import warnings
from sklearn import linear_model, preprocessing
from sklearn.model_selection import train_test_split
warnings.filterwarnings('ignore')

# %%
articles = pd.read_csv('../Datasets/articles_filter_en.csv', sep='\t', encoding='utf-8', index_col=[0])

# %%
for l in articles.site_categories.unique():
    if 'tech' in l:
        print(l)
# Out:
# ['tech']
# ['computer_certification', 'tech']
# ['news', 'tech']
# ['law_government_and_politics', 'home_and_garden', 'tech', 'hacking', 'environmental_safety', 'us_government_resources']
# ['shopping', 'media', 'cell_phones', 'tech']
# ['windows', 'tech']
# ['cell_phones', 'tech']
# ['pc_support', 'tech']
# ['media', 'tech']
# ['tech', 'email']
# ['tech', 'law_government_and_politics', 'us_government_resources']
# ['databases', 'tech', 'law_government_and_politics', 'us_government_resources']
# ['biotech_biomedical', 'business']
# ['javascript', 'tech']
# ['media', 'cell_phones', 'tech', 'computer_reviews']
# ['windows', 'hobbies_and_interests', 'tech', 'video_and_computer_games']
# ['search_engine', 'media', 'tech']
# ['media', 'hacking', 'tech']

# %%
articles.columns
# Out:
# Index(['site', 'site_type', 'site_section', 'site_categories', 'domain_rank',
#        'country', 'author', 'published', 'title', 'text', 'highlightText',
#        'highlightTitle', 'language', 'rating', 'locations_pos',
#        'locations_neu', 'locations_neg', 'organizations_pos',
#        'organizations_neu', 'organizations_neg', 'persons_pos', 'persons_neu',
#        'persons_neg', 'rank', 'website', 'category', 'change',
#        'avg_visit_duration', 'pages/visit', 'bounce_rate', 'subcategory'],
#       dtype='object')

# %%
X = articles[['site_type', 'site_categories', 'domain_rank', 'country', 'avg_visit_duration', 'pages/visit', 'bounce_rate', 'rating']]
y = articles[['category', 'subcategory', 'site_categories', 'site_section']]

X['has_author'] = np.where(articles.author.isnull() , False, True)

X['has_person_pos'] = (not articles.persons_pos.empty)
X['has_person_neu'] = (not articles.persons_neu.empty)
X['has_person_neg'] = (not articles.persons_neg.empty)
X['has_organizations_pos'] = (not articles.organizations_pos.empty)
X['has_organizations_neu'] = (not articles.organizations_neu.empty)
X['has_organizations_neg'] = (not articles.organizations_neg.empty)

def get_sec(time_str):
    h, m, s = str(time_str).split(':')
    return int(h) * 3600 + int(m) * 60 + int(s)

X.avg_visit_duration = X.avg_visit_duration.map(get_sec)

y['class'] = np.where((y.category == 'News and Media') & ('tech' not in y.site_categories) , 'News', 'Science')

# %%
y.loc[(y.category == 'Health')].groupby(['category', 'subcategory','site_categories']).size()
# Out:
# category  subcategory               site_categories
# Health    Child Health              ['pregnancy', 'family_and_parenting']                                      100
#           Conditions and Diseases   ['senor_health', 'mens_health', 'health', 'arthritis', 'womens_health']     96
#                                     []                                                                           2
#           Education and Resources   ['social']                                                                 100
#           Healthcare Industry       ['health']                                                                   1
#           Medicine                  ['orthopedics', 'health']                                                   20
#                                     ['uncategorized']                                                            5
#                                     []                                                                           5
#           Mental Health             ['health', 'psychology_psychiatry', 'incest_abuse_support']                100
# 4      ['hobbies_and_interests', 'video_and_computer_...
# 5      ['hobbies_and_interests', 'video_and_computer_...
# 6      ['hobbies_and_interests', 'video_and_computer_...
# 7      ['hobbies_and_interests', 'video_and_computer_...
# 8      ['hobbies_and_interests', 'video_and_computer_...
# 9      ['hobbies_and_interests', 'video_and_computer_...
# 10     ['hobbies_and_interests', 'video_and_computer_...
# 11     ['hobbies_and_interests', 'video_and_computer_...
# 12     ['hobbies_and_interests', 'video_and_computer_...
# 13     ['hobbies_and_interests', 'video_and_computer_...
# 14     ['hobbies_and_interests', 'video_and_computer_...
# 15     ['hobbies_and_interests', 'video_and_computer_...
# 16     ['hobbies_and_interests', 'video_and_computer_...
# 17     ['hobbies_and_interests', 'video_and_computer_...
# 18     ['hobbies_and_interests', 'video_and_computer_...
# 19     ['hobbies_and_interests', 'video_and_computer_...
# 20                                              ['tech']
# 21     ['hobbies_and_interests', 'video_and_computer_...
# 22     ['hobbies_and_interests', 'video_and_computer_...
# 23     ['hobbies_and_interests', 'video_and_computer_...
# 24     ['hobbies_and_interests', 'video_and_computer_...
# 25     ['hobbies_and_interests', 'video_and_computer_...
# 422                                            ['media']
# 423                                            ['media']
# 424                                            ['media']
# 425                                            ['media']
# ...                                                  ...
# 12065                                           ['tech']
# 12066                                           ['tech']
# 12067                                           ['tech']
# 12068                                           ['tech']
# 12069                                           ['tech']
# 12070                                           ['tech']
# 12071                                           ['tech']
# 12072                                           ['tech']
# 12073                                           ['tech']
# 12074                                           ['tech']
# 12075                                           ['tech']
# 12076                                           ['tech']
# 12077                                           ['tech']
# 12078                                           ['tech']
# 12079                                           ['tech']
# 12080                                           ['tech']
# 12081                                           ['tech']
# 12082                                           ['tech']
# 12083                                           ['tech']
# 12084                                           ['tech']
# 12085                                           ['tech']
# 12086                                           ['tech']
# 12087                                           ['tech']
# 12088                                           ['tech']
# 12089                                           ['tech']
# 12090                                           ['tech']
# 12091                                           ['tech']
# 12092                                           ['tech']
# 12093                                           ['tech']
# 12094                                           ['tech']
#
#                                             site_section class
# 0      http://forum.telecharger.01net.com/forum/high-...  News
# 1      http://forum.telecharger.01net.com/forum/high-...  News
# 2      http://forum.telecharger.01net.com/forum/high-...  News
# 3      http://forum.telecharger.01net.com/forum/high-...  News
# 4      http://forum.telecharger.01net.com/forum/high-...  News
# 5      http://forum.telecharger.01net.com/forum/high-...  News
# 6      http://forum.telecharger.01net.com/forum/high-...  News
# 7      http://forum.telecharger.01net.com/forum/high-...  News
# 8      http://forum.telecharger.01net.com/forum/high-...  News
# 9      http://forum.telecharger.01net.com/forum/high-...  News
# 10     http://forum.telecharger.01net.com/forum/high-...  News
# 11     http://forum.telecharger.01net.com/forum/high-...  News
# 12     http://forum.telecharger.01net.com/forum/high-...  News
# 13     http://forum.telecharger.01net.com/forum/high-...  News
# 14     http://forum.telecharger.01net.com/forum/high-...  News
# 15     http://forum.telecharger.01net.com/forum/high-...  News
# 16     http://forum.telecharger.01net.com/forum/high-...  News
# 17     http://forum.telecharger.01net.com/forum/high-...  News
# 18     http://forum.telecharger.01net.com/forum/high-...  News
# 19     http://forum.telecharger.01net.com/forum/high-...  News
# 20                   http://www.w4society.com/?feed=rss2  News
# 21     http://forum.telecharger.01net.com/forum/high-...  News
# 22     http://forum.telecharger.01net.com/forum/high-...  News
# 23     http://forum.telecharger.01net.com/forum/high-...  News
# 24     http://forum.telecharger.01net.com/forum/high-...  News
# 25     http://forum.telecharger.01net.com/forum/high-...  News
# 422                     https://arstechnica.com/gadgets/  News
# 423                      https://arstechnica.com/gaming/  News
# 424       http://feeds.arstechnica.com/arstechnica/index  News
# 425       http://feeds.arstechnica.com/arstechnica/index  News
# ...                                                  ...   ...
# 12065          http://downloads.zdnet.com/recent/rss.xml  News
# 12066          http://downloads.zdnet.com/recent/rss.xml  News
# 12067          http://downloads.zdnet.com/recent/rss.xml  News
# 12068          http://downloads.zdnet.com/recent/rss.xml  News
# 12069          http://downloads.zdnet.com/recent/rss.xml  News
# 12070          http://downloads.zdnet.com/recent/rss.xml  News
# 12071          http://downloads.zdnet.com/recent/rss.xml  News
# 12072          http://downloads.zdnet.com/recent/rss.xml  News
# 12073          http://downloads.zdnet.com/recent/rss.xml  News
# 12074          http://downloads.zdnet.com/recent/rss.xml  News
# 12075          http://downloads.zdnet.com/recent/rss.xml  News
# 12076          http://downloads.zdnet.com/recent/rss.xml  News
# 12077          http://downloads.zdnet.com/recent/rss.xml  News
# 12078          http://downloads.zdnet.com/recent/rss.xml  News
# 12079          http://downloads.zdnet.com/recent/rss.xml  News
# 12080          http://downloads.zdnet.com/recent/rss.xml  News
# 12081          http://downloads.zdnet.com/recent/rss.xml  News
# 12082          http://downloads.zdnet.com/recent/rss.xml  News
# 12083          http://downloads.zdnet.com/recent/rss.xml  News
# 12084          http://downloads.zdnet.com/recent/rss.xml  News
# 12085          http://downloads.zdnet.com/recent/rss.xml  News
# 12086          http://downloads.zdnet.com/recent/rss.xml  News
# 12087          http://downloads.zdnet.com/recent/rss.xml  News
# 12088          http://downloads.zdnet.com/recent/rss.xml  News
# 12089          http://downloads.zdnet.com/recent/rss.xml  News
# 12090          http://downloads.zdnet.com/recent/rss.xml  News
# 12091          http://downloads.zdnet.com/recent/rss.xml  News
# 12092          http://downloads.zdnet.com/recent/rss.xml  News
# 12093          http://downloads.zdnet.com/recent/rss.xml  News
# 12094          http://downloads.zdnet.com/recent/rss.xml  News
#
# [1800 rows x 5 columns]

# %% [markdown]
# # Training

# %%
le = preprocessing.LabelEncoder()
X_2 = X.apply(le.fit_transform)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_2, y['class'], test_size=0.4, random_state=0)

logreg = linear_model.LogisticRegression(C=1e5)

clf = logreg.fit(X_2, y['class'])

# %% [markdown]
# # Validation

# %%
clf.score(X_test, y_test)
# Out:
# 0.79011366640232616
