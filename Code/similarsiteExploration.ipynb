# %%
import pandas as pd 
import glob

path ='../similarsites_urls_data'

allFiles = glob.glob(path + "/*.csv")
frame = pd.DataFrame()
list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_)

frame.columns
frame.drop_duplicates('Website ')
# Out:
#      Rank                                            Website   \
# 0        1         cookpad.com website analytics cookpad.com
# 1        2         tabelog.com website analytics tabelog.com
# 2        3       hotpepper.jp website analytics hotpepper.jp
# 3        4             tesco.com website analytics tesco.com
# 4        5       dianping.com website analytics dianping.com
# 5        6               asda.com website analytics asda.com
# 6        7   allrecipes.com website analytics allrecipes.com
# 7        8           zomato.com website analytics zomato.com
# 8        9         chefkoch.de website analytics chefkoch.de
# 9       10       pizzahut.com website analytics pizzahut.com
# 10      11         dominos.com website analytics dominos.com
# 11      12   tudogostoso.com.br website analytics tudogost...
# 12      13         gnavi.co.jp website analytics gnavi.co.jp
# 13      14       marmiton.org website analytics marmiton.org
# ...
