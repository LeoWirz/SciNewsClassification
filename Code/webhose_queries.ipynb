# %%
import pandas as pd 
import glob
import re

from webhoseQueries import *

# %%
path ='../similarsites_urls_data'

allFiles = glob.glob(path + "/*.csv")
frame = pd.DataFrame()
list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_).reset_index(drop=True)

# %% [markdown]
# # url list

# %%
# rename columns correctly
frame.columns = ['rank', 'website', 'category', 'change', 'avg_visit_duration', 'pages/visit', 'bounce_rate']

# clean domain 
frame['website'] = frame['website'].map(lambda x: re.search('([a-z0-9]*\.)+[a-z0-9]*',x).group(0))

# split categories and subcategories
frame[['category', 'subcategory']] = pd.DataFrame(frame.category.str.split(' > ').tolist(), columns = ['category','subcatergory'])

# percentage string to float/100
frame['bounce_rate'] = frame['bounce_rate'].map(lambda x: float(str(x).strip('%'))/100)

# datetime for duration ???


# drop duplicate, for now they have the same categories so it's ok to do so
frame = frame.drop_duplicates(['website'])

# %%
# to check if we have duplicate sites with different categories
frame[frame.duplicated(['website'], keep=False) & ~ frame.duplicated(['category'],keep=False)].sort_values('website')
# Out:
# Empty DataFrame
# Columns: [rank, website, category, change, avg_visit_duration, pages/visit, bounce_rate, subcategory]
# Index: []

# %%
# load csv articles obtained with this list of websites
df_articles = pd.DataFrame.from_csv('../Datasets/articles.csv', sep='\t', encoding='utf-8')
# Out:
# C:\Users\Leonovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls

# %%
# join the 2 dataframes together
result = pd.merge(df_articles, frame, left_on = 'site', right_on = 'website')

# %%
result.groupby(result.category).count()
# Out:
#                 site  site_type  site_section  site_categories  domain_rank  \
# category
# Food and Drink   992        992           777              992          840
# Health          1847       1847          1384             1847         1721
# News and Media  7813       7813          6743             7741         7559
# Science         1569       1569          1355             1541         1540
#
#                 country  author  published  title  text     ...       \
# category                                                    ...
# Food and Drink      992     736        992    938   992     ...
# Health             1845    1181       1847   1577  1847     ...
# News and Media     7700    5330       7741   6070  7740     ...
# Science            1492     952       1541   1538  1541     ...
#
#                 persons_neu  persons_neg  rank  website  category  change  \
# category
# Food and Drink          992          992   992      992       992     992
# Health                 1847         1847  1847     1847      1847    1847
# News and Media         7741         7741  7813     7813      7813    7813
# Science                1541         1541  1569     1569      1569    1569
#
#                 avg_visit_duration  pages/visit  bounce_rate  subcategory
# category
# Food and Drink                 992          992          992          927
# Health                        1847         1847         1847         1073
# News and Media                7813         7813         7813         5612
# Science                       1569         1569         1569          735
#
# [4 rows x 31 columns]

# %%
result.groupby(result.subcategory).count()
# Out:
#                             site  site_type  site_section  site_categories  \
# subcategory
# Biology                      266        266           238              266
# Chemistry                    216        216           215              216
# Child Health                1756       1756          1756             1756
# Conditions and Diseases      100        100            76              100
# Cooking and Recipes         1022       1022           937             1022
# Education and Resources      100        100           100              100
# Environment                  119        119           116              119
# Food and Grocery Retailers    11         11             0               11
# Healthcare Industry            1          1             0                1
# Magazines and E Zines        172        172           160              172
# Math                           3          3             3                3
# Medicine                      30         30            18               30
# Mental Health                100        100            96              100
# Newspapers                  3254       3254          2952             3206
# Nutrition                    476        476           336              476
# Pharmacy                     100        100           100              100
# Physics                       35         35            32               35
# Products and Shopping         52         52            24               52
# Public Health and Safety       1          1             1                1
# Restaurants and Delivery      59         59            52               59
# Social Sciences              113        113            64              113
# Sports News                  205        205           135              205
# Technology News             3244       3244          3025             3244
# Vegetarian and Vegan         276        276           164              276
# Weather                      202        202           111              202
#
#                             domain_rank  country  author  published  title  \
# subcategory
# Biology                             265      265     233        266    266
# Chemistry                           216      216     216        216    216
# Child Health                       1756     1756    1740       1756    266
# Conditions and Diseases             100       98      73        100     98
# Cooking and Recipes                 922     1022     938       1022    601
# Education and Resources             100      100       0        100    100
# Environment                         119      119      89        119    119
# Food and Grocery Retailers           11       11       0         11     11
# Healthcare Industry                   1        1       0          1      1
# Magazines and E Zines               172      172     123        172     81
# Math                                  3        3       3          3      3
# Medicine                             30       30       9         30     30
# Mental Health                       100      100      96        100    100
# Newspapers                         3091     3203    2357       3206   2277
# Nutrition                           450      476     356        476    374
# Pharmacy                            100      100      62        100     43
# Physics                              35       35      16         35     35
# Products and Shopping                52       52      37         52     52
# Public Health and Safety              1        1       0          1      1
# Restaurants and Delivery             59       59      26         59     59
# Social Sciences                     113      113     105        113    110
# Sports News                         205      205     102        205    195
# Technology News                    3162     3215    2717       3244   1899
# Vegetarian and Vegan                224      276     169        276    262
# Weather                             202      201      52        202    191
#
#                             text     ...       persons_neu  persons_neg  rank  \
# subcategory                          ...
# Biology                      266     ...               266          266   266
# Chemistry                    216     ...               216          216   216
# Child Health                1756     ...              1756         1756  1756
# Conditions and Diseases      100     ...               100          100   100
# Cooking and Recipes         1022     ...              1022         1022  1022
# Education and Resources      100     ...               100          100   100
# Environment                  119     ...               119          119   119
# Food and Grocery Retailers    11     ...                11           11    11
# Healthcare Industry            1     ...                 1            1     1
# Magazines and E Zines        172     ...               172          172   172
# Math                           3     ...                 3            3     3
# Medicine                      30     ...                30           30    30
# Mental Health                100     ...               100          100   100
# Newspapers                  3205     ...              3206         3206  3254
# Nutrition                    476     ...               476          476   476
# Pharmacy                     100     ...               100          100   100
# Physics                       35     ...                35           35    35
# Products and Shopping         52     ...                52           52    52
# Public Health and Safety       1     ...                 1            1     1
# Restaurants and Delivery      59     ...                59           59    59
# Social Sciences              113     ...               113          113   113
# Sports News                  205     ...               205          205   205
# Technology News             3244     ...              3244         3244  3244
# Vegetarian and Vegan         276     ...               276          276   276
# Weather                      202     ...               202          202   202
#
#                             website  category  change  avg_visit_duration  \
# subcategory
# Biology                         266       266     266                 266
# Chemistry                       216       216     216                 216
# Child Health                   1756      1756    1756                1756
# Conditions and Diseases         100       100     100                 100
# Cooking and Recipes            1022      1022    1022                1022
# Education and Resources         100       100     100                 100
# Environment                     119       119     119                 119
# Food and Grocery Retailers       11        11      11                  11
# Healthcare Industry               1         1       1                   1
# Magazines and E Zines           172       172     172                 172
# Math                              3         3       3                   3
# Medicine                         30        30      30                  30
# Mental Health                   100       100     100                 100
# Newspapers                     3254      3254    3254                3254
# Nutrition                       476       476     476                 476
# Pharmacy                        100       100     100                 100
# Physics                          35        35      35                  35
# Products and Shopping            52        52      52                  52
# Public Health and Safety          1         1       1                   1
# Restaurants and Delivery         59        59      59                  59
# Social Sciences                 113       113     113                 113
# Sports News                     205       205     205                 205
# Technology News                3244      3244    3244                3244
# Vegetarian and Vegan            276       276     276                 276
# Weather                         202       202     202                 202
#
#                             pages/visit  bounce_rate  subcategory
# subcategory
# Biology                             266          266          266
# Chemistry                           216          216          216
# Child Health                       1756         1756         1756
# Conditions and Diseases             100          100          100
# Cooking and Recipes                1022         1022         1022
# Education and Resources             100          100          100
# Environment                         119          119          119
# Food and Grocery Retailers           11           11           11
# Healthcare Industry                   1            1            1
# Magazines and E Zines               172          172          172
# Math                                  3            3            3
# Medicine                             30           30           30
# Mental Health                       100          100          100
# Newspapers                         3254         3254         3254
# Nutrition                           476          476          476
# Pharmacy                            100          100          100
# Physics                              35           35           35
# Products and Shopping                52           52           52
# Public Health and Safety              1            1            1
# Restaurants and Delivery             59           59           59
# Social Sciences                     113          113          113
# Sports News                         205          205          205
# Technology News                    3244         3244         3244
# Vegetarian and Vegan                276          276          276
# Weather                             202          202          202
#
# [25 rows x 31 columns]

# %%
# filter by country that have most of their articles in english (derived manually)

english_country = ['FR', 'US', 'CH', 'EU', 'GB',
                   'CA', 'PW', 'ID', 'ES', 'LI',
                   'IL', 'IN', 'VN', 'NL', 'TW', 
                   'HR', 'KS', 'HK', 'KR', 'SG',
                   'AU', 'DK', 'NO']

result_english = result[result.country.isin(english_country)]

# %%
# save the frame 
frame.to_csv('../Datasets/urls_list_with_labels.csv', sep='\t', encoding='utf-8')
result_english.to_csv('../Datasets/articles_filter_en.csv', sep='\t', encoding='utf-8')

# %% [markdown]
# # articles query
# This part creates all jsons with articles in SciNewsClassification\webhose_data
# DO NOT LAUNCH IT, BECAUSE IT WILL USE ALL QUERIES FROM WEBHOSE !!!!

# %%
def fetch_all_articles():
    for domain in frame.website:
        print(domain)
        get_pages_into_json(domain)

# %%
get_pages_into_json('', 1000)

# %% [markdown]
# # TEST

# %%
import newspaper
def articles_from_domain(domain):
    papers = newspaper.build(domain, language='en')
    return papers.articles

# %%
for domain in frame.website:
    print(domain)
    papers = newspaper.build('http://www.veggieboards.com/', language='en')
    print(papers.size())
# Out:
# happycow.net
# 0
# irrawaddy.com
# 0
# veganricha.com
# 0
# froh.de
# 0
# veggieboards.com
# 0
# rawdd.com
# 0
# stadionowioprawcy.net
# 0
# vegansociety.com
# 0
# vebu.de
# 0
# chooseveg.com
# 0
# farmfreshtoyou.com
# 0
# se.com.br
# 0
# holycowvegan.net
# 0
# vegnews.com
# 0
# msrawytop.com
# 0
# vegetarisch.de
# 0
# veganuary.com
# 0
# vegan.com
# 0
# ilovevegan.com
# 0
# vegetarian.ru
# 0
# vegancoach.com
# 0
# gesund.de
# 0
# theflamingvegan.com
# 0
# suiis.com
# 0
# biserawalpindi.edu.pk
# 0
# vegetarianismo.net
# 0
# brandnewvegan.com
# 0
# vegweb.com
# 0
# veganessentials.com
# 0
# cntvan.com
# 0
# veggiecommunity.org
# 0
# vrg.org
# 0
# followyourheart.com
# 0
# mania.com
# 0
# veganbodybuilding.com
# 0
# raws.org
# 0
# sunwarrior.com
# 0
# cantinhovegetariano.com.br
# 0
# veganfoodlover.com
# 0
# veganstart.de
# 0
# rawan.net
# 0
# job.lzu.edu.cn
# 0
# deutschlandistvegan.de
# 0
# vegancuts.com
# 0
# vegsoc.org
# 0
# veganguerilla.de
# 0
# vegpool.de
# 0
# vegfest.co.uk
# 0
# veg.by
# 0
# cookpad.com
